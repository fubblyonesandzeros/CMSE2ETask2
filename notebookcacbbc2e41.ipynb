# %%
# !git clone "https://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@github.com/danny-1k/ML4SciTest2"
# Out:
# Cloning into 'ML4SciTest2'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 52 (delta 16), reused 49 (delta 13), pack-reused 0
# Unpacking objects: 100% (52/52), 7.18 KiB | 668.00 KiB/s, done.

# %%
import os

os.chdir("ML4SciTest2/src")

# %%
# !python train_resnet.py
# Out:
# ...
# 100%|█████████████████████████████████████████| 118/118 [00:30<00:00,  3.90it/s]
# Epch (1) Trn Loss (0.695) Tst Loss (0.691) Trn Acc (0.518) Tst Loss (0.506)
# ...
# 100%|█████████████████████████████████████████| 118/118 [00:30<00:00,  3.91it/s]
# Epch (2) Trn Loss (0.669) Tst Loss (0.687) Trn Acc (0.607) Tst Loss (0.538)
# ...
# 100%|█████████████████████████████████████████| 118/118 [00:30<00:00,  3.91it/s]
# Epch (3) Trn Loss (0.632) Tst Loss (0.739) Trn Acc (0.653) Tst Loss (0.509)
# ...
# 100%|█████████████████████████████████████████| 118/118 [00:30<00:00,  3.91it/s]
# Epch (4) Trn Loss (0.624) Tst Loss (1.269) Trn Acc (0.665) Tst Loss (0.495)
# ...
# 100%|█████████████████████████████████████████| 118/118 [00:30<00:00,  3.91it/s]
# Epch (5) Trn Loss (0.621) Tst Loss (0.692) Trn Acc (0.668) Tst Loss (0.545)
# ...
# 100%|█████████████████████████████████████████| 118/118 [00:30<00:00,  3.91it/s]
# Epch (6) Trn Loss (0.618) Tst Loss (0.679) Trn Acc (0.671) Tst Loss (0.495)
# ...
